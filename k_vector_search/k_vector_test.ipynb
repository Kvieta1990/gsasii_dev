# %% [markdown]
# # List of optimal k vector alternatives

# %%
k_opt = [
    [0.26, 0.22, 1.48],
    [0.49, 0.27, 1.39],
    [0.21, 0.27, 1.44],
    [0.18, 0.28, 1.43],
    [0.2, 0.27, 1.46],
    [0.17, 0.28, 1.45],
    [0.49, 0.26, 1.43],
    [0.26, 0.23, 1.47],
    [0.5, 0.27, 1.4],
    [0.49, 0.26, 1.46]
]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# > The `k_gt` is the ground truth (?)

# %% [markdown]
# ## #1 -> k = [0.26, 0.22, 1.48]

# %%
k_trial = {
    "9.507560751101375": 9.498671273212546,
    "4.769096051854822": 4.765169843221434,
    "4.5362821812106136": 4.5645042787849714,
    "4.144601496496338": 4.154629462342267,
    "3.6350318051362707": 3.5999354788629634,
    "3.5033746207914023": 3.454895876982807,
    "3.310987362236161": 3.321648341871635,
    "2.8482031605609426": 2.8481499419214895,
    "2.795775653267508": 2.8253552150406507,
    "2.6280789916159955": 2.6061706171518013,
    "2.5559135238229738": 2.5569396208257356,
    "2.4218697209141737": 2.435506600706961,
    "2.3819042368347394": 2.3771317604500464
}

k_gt = {
    "9.507560751101375": 9.409086543981392,
    "4.769096051854822": 4.7864713055542705,
    "4.5362821812106136": 4.731318305935864,
    "4.144601496496338": 4.129298896501025,
    "3.6350318051362707": 3.5371409949337105,
    "3.5033746207914023": 3.4861443966201935,
    "3.310987362236161": 3.296476929487278,
    "2.8482031605609426": 2.8509318695983876,
    "2.795775653267508": 2.7715684949723958,
    "2.6280789916159955": 2.6223473883334876,
    "2.5559135238229738": 2.553625387818443,
    "2.4218697209141737": 2.4226070512416835,
    "2.3819042368347394": 2.380756355433843
}

# %%
plt.figure(figsize=(13, 5))
ax = plt.gca()

for key, item in k_trial.items():
    plt.vlines(x=float(key), ymin=0.2, ymax=0.8,
               colors='black',
               label='Observed Peaks')
    plt.vlines(x=item, ymin=1.0, ymax=1.6,
               colors='blue',
               label='k = [0.26, 0.22, 1.48]')

for _, item in k_gt.items():
    plt.vlines(x=item, ymin=1.8, ymax=2.4,
               colors='red',
               label='k = [0.33, 0.21, 1.5]')    
    
ax.set_xticks(range(2, 11))
ax.set_xticklabels(range(2, 11), fontsize=15)
ax.set_xlabel(r'd ($\AA$)', fontsize=18)
ax.set_yticks([.5, 1.3, 2.1])
ax.set_yticklabels(
    [
        'Observed',
        'k = [0.26, 0.22, 1.48]',
        'k = [0.33, 0.21, 1.5]'
    ],
    fontsize=15
)

plt.show()

# %% [markdown]
# ## #2 -> k = [0.49, 0.27, 1.39]

# %%
k_trial = {
    "9.507560751101375": 9.524557568200366,
    "4.769096051854822": 4.74967947769806,
    "4.5362821812106136": 4.563038653948603,
    "4.144601496496338": 4.14902964529866,
    "3.6350318051362707": 3.6367031909647896,
    "3.5033746207914023": 3.506468841165684,
    "3.310987362236161": 3.3315004631561638,
    "2.8482031605609426": 2.82861862173398,
    "2.795775653267508": 2.728750672210832,
    "2.6280789916159955": 2.6300781023650672,
    "2.5559135238229738": 2.544641603862893,
    "2.4218697209141737": 2.4086733354452297,
    "2.3819042368347394": 2.373649183547538
}

plt.figure(figsize=(13, 5))
ax = plt.gca()

for key, item in k_trial.items():
    plt.vlines(x=float(key), ymin=0.2, ymax=0.8,
               colors='black',
               label='Observed Peaks')
    plt.vlines(x=item, ymin=1.0, ymax=1.6,
               colors='blue',
               label='k = [0.49, 0.27, 1.39]')

for _, item in k_gt.items():
    plt.vlines(x=item, ymin=1.8, ymax=2.4,
               colors='red',
               label='k = [0.33, 0.21, 1.5]')    
    
ax.set_xticks(range(2, 11))
ax.set_xticklabels(range(2, 11), fontsize=15)
ax.set_xlabel(r'd ($\AA$)', fontsize=18)
ax.set_yticks([.5, 1.3, 2.1])
ax.set_yticklabels(
    [
        'Observed',
        'k = [0.49, 0.27, 1.39]',
        'k = [0.33, 0.21, 1.5]'
    ],
    fontsize=15
)

plt.show()

# %% [markdown]
# ## #3 -> k = [0.21, 0.27, 1.44]

# %%
k_trial = {
    "9.507560751101375": 9.503343671984299,
    "4.769096051854822": 4.789824418288914,
    "4.5362821812106136": 4.548601962395907,
    "4.144601496496338": 4.120365334286772,
    "3.6350318051362707": 3.5884850420674557,
    "3.5033746207914023": 3.4941533501245434,
    "3.310987362236161": 3.2787481718411278,
    "2.8482031605609426": 2.8521914004352706,
    "2.795775653267508": 2.846082592488644,
    "2.6280789916159955": 2.617220631311689,
    "2.5559135238229738": 2.5575082202411665,
    "2.4218697209141737": 2.3982963747198536,
    "2.3819042368347394": 2.375140971405743
}

plt.figure(figsize=(13, 5))
ax = plt.gca()

for key, item in k_trial.items():
    plt.vlines(x=float(key), ymin=0.2, ymax=0.8,
               colors='black',
               label='Observed Peaks')
    plt.vlines(x=item, ymin=1.0, ymax=1.6,
               colors='blue',
               label='k = [0.21, 0.27, 1.44]')

for _, item in k_gt.items():
    plt.vlines(x=item, ymin=1.8, ymax=2.4,
               colors='red',
               label='k = [0.33, 0.21, 1.5]')    
    
ax.set_xticks(range(2, 11))
ax.set_xticklabels(range(2, 11), fontsize=15)
ax.set_xlabel(r'd ($\AA$)', fontsize=18)
ax.set_yticks([.5, 1.3, 2.1])
ax.set_yticklabels(
    [
        'Observed',
        'k = [0.21, 0.27, 1.44]',
        'k = [0.33, 0.21, 1.5]'
    ],
    fontsize=15
)

plt.show()

# %% [markdown]
# ## #10 -> k = [0.49, 0.26, 1.46]

# %%
k_trial = {
    "9.507560751101375": 9.51366587019854,
    "4.769096051854822": 4.808598639913381,
    "4.5362821812106136": 4.561839436843272,
    "4.144601496496338": 4.118051566552446,
    "3.6350318051362707": 3.642189329808335,
    "3.5033746207914023": 3.5219272198020737,
    "3.310987362236161": 3.3217268318899786,
    "2.8482031605609426": 2.8536671916922436,
    "2.795775653267508": 2.7323546019087828,
    "2.6280789916159955": 2.63099895318848,
    "2.5559135238229738": 2.524389600944518,
    "2.4218697209141737": 2.4109195490495017,
    "2.3819042368347394": 2.382609745307603
}

plt.figure(figsize=(13, 5))
ax = plt.gca()

for key, item in k_trial.items():
    plt.vlines(x=float(key), ymin=0.2, ymax=0.8,
               colors='black',
               label='Observed Peaks')
    plt.vlines(x=item, ymin=1.0, ymax=1.6,
               colors='blue',
               label='k = [0.49, 0.26, 1.46]')

for _, item in k_gt.items():
    plt.vlines(x=item, ymin=1.8, ymax=2.4,
               colors='red',
               label='k = [0.33, 0.21, 1.5]')    
    
ax.set_xticks(range(2, 11))
ax.set_xticklabels(range(2, 11), fontsize=15)
ax.set_xlabel(r'd ($\AA$)', fontsize=18)
ax.set_yticks([.5, 1.3, 2.1])
ax.set_yticklabels(
    [
        'Observed',
        'k = [0.49, 0.26, 1.46]',
        'k = [0.33, 0.21, 1.5]'
    ],
    fontsize=15
)

plt.show()

# %% [markdown]
# # Manual Test -> k = [0., 0., 0.]
#
# > The purpose is to confirm the d spacing calculation is implemented correctly
#
# > Here, the d-spacing included in the 4th column is from VESTA, as the ground truth to compare to

# %%
# The lattice vectors of the R-3m structure as included in the PCR file
latt_vec = np.array([
    [6.430117, -3.712430, -0.000000],
    [0.000000, 7.424860, -0.000000],
    [0.000000, 0.000000, 19.497026]
])

k_vec = np.array([0., 0., 0.])

# Construct the reciprocal space vectors
vol = np.dot(latt_vec[0], np.cross(latt_vec[1], latt_vec[2]))
b1 = 2. * np.pi / vol * np.cross(latt_vec[1], latt_vec[2])
b2 = 2. * np.pi / vol * np.cross(latt_vec[2], latt_vec[0])
b3 = 2. * np.pi / vol * np.cross(latt_vec[0], latt_vec[1])
rec_latt = np.array([b1, b2, b3])

hkl_file = "./files/Joe_Na2Mn3Cl8/k_general_dummy.hkl"
with open(hkl_file, "r") as f:
    all_lines = f.readlines()

hkl_refls = [
    [float(item) for item in line.split()[:4]] for line in all_lines[1:]
]

print_str = "{:>3s}{:>3s}{:>3s}"
print_str += "{:>12s}{:>12s}{:>12s}"
print_str += "{:>12s}{:>12s}"
print(
    print_str.format(
        "h", "k", "l",
        "d", "d_hkl_p_k", "d_hkl_m_k",
        "diff_p", "diff_m"
    )
)

for hkl in hkl_refls:
    hkl_tmp = np.array(hkl[:3])

    hkl_p_k = hkl_tmp + k_vec
    k_cart = np.matmul(
        hkl_p_k,
        rec_latt
    )
    d_hkl_p_k = 2. * np.pi / np.linalg.norm(k_cart)

    hkl_m_k = hkl_tmp - k_vec
    k_cart = np.matmul(
        hkl_m_k,
        rec_latt
    )
    d_hkl_m_k = 2. * np.pi / np.linalg.norm(k_cart)

    print_str = "{:3d}{:3d}{:3d}"
    print_str += "{:12.5F}{:12.5F}{:12.5F}"
    print_str += "{:12.5F}{:12.5F}"

    print(
        print_str.format(
            int(hkl[0]), int(hkl[1]), int(hkl[2]),
            hkl[3], d_hkl_p_k, d_hkl_m_k,
            abs(d_hkl_p_k - hkl[3]), abs(d_hkl_m_k - hkl[3])
        )
    )
# Out:
#   h  k  l           d   d_hkl_p_k   d_hkl_m_k      diff_p      diff_m
#   0  0  3     6.49901     6.49901     6.49901     0.00000     0.00000
#   1  0  1     6.10659     6.10659     6.10659     0.00000     0.00000
#   0  1  2     5.36762     5.36762     5.36762     0.00000     0.00000
#   1  0  4     3.88437     3.88437     3.88437     0.00000     0.00000
#   1  1  0     3.71243     3.71243     3.71243     0.00000     0.00000
#   0  1  5     3.33422     3.33422     3.33422     0.00000     0.00000
#   0  0  6     3.24950     3.24950     3.24950     0.00000     0.00000
#   1  1  3     3.22357     3.22357     3.22357     0.00000     0.00000
#   0  2  1     3.17222     3.17222     3.17222     0.00000     0.00000
#   2  0  2     3.05329     3.05329     3.05329     0.00000     0.00000
#   0  2  4     2.68381     2.68381     2.68381     0.00000     0.00000
#   1  0  7     2.55582     2.55582     2.55582     0.00000     0.00000
# ...

# %% [markdown]
# # Manual Test -> k = [0.33, 0.21, 1.5]

# %%
# The lattice vectors of the R-3m structure as included in the PCR file
latt_vec = np.array([
    [6.430117, -3.712430, -0.000000],
    [0.000000, 7.424860, -0.000000],
    [0.000000, 0.000000, 19.497026]
])

k_vec = np.array([0.33, 0.21, 1.5])

# Construct the reciprocal space vectors
vol = np.dot(latt_vec[0], np.cross(latt_vec[1], latt_vec[2]))
b1 = 2. * np.pi / vol * np.cross(latt_vec[1], latt_vec[2])
b2 = 2. * np.pi / vol * np.cross(latt_vec[2], latt_vec[0])
b3 = 2. * np.pi / vol * np.cross(latt_vec[0], latt_vec[1])
rec_latt = np.array([b1, b2, b3])

hkl_file = "./files/Joe_Na2Mn3Cl8/k_general_dummy.hkl"
with open(hkl_file, "r") as f:
    all_lines = f.readlines()

hkl_refls = [
    [float(item) for item in line.split()[:4]] for line in all_lines[1:]
]

print_str = "{:>3s}{:>3s}{:>3s}"
print_str += "{:>12s}{:>12s}{:>12s}"
print(
    print_str.format(
        "h", "k", "l",
        "d", "d_hkl_p_k", "d_hkl_m_k"
    )
)

for hkl in hkl_refls:
    hkl_tmp = np.array(hkl[:3])

    hkl_p_k = hkl_tmp + k_vec
    k_cart = np.matmul(
        hkl_p_k,
        rec_latt
    )
    d_hkl_p_k = 2. * np.pi / np.linalg.norm(k_cart)

    hkl_m_k = hkl_tmp - k_vec
    k_cart = np.matmul(
        hkl_m_k,
        rec_latt
    )
    d_hkl_m_k = 2. * np.pi / np.linalg.norm(k_cart)

    print_str = "{:3d}{:3d}{:3d}"
    print_str += "{:12.5F}{:12.5F}{:12.5F}"

    if d_hkl_p_k > 2. or d_hkl_m_k > 2.:
        print(
            print_str.format(
                int(hkl[0]), int(hkl[1]), int(hkl[2]),
                hkl[3], d_hkl_p_k, d_hkl_m_k
            )
        )
# Out:
#   h  k  l           d   d_hkl_p_k   d_hkl_m_k
#   0  0  3     6.49901     4.12930     9.40909
#   1  0  1     6.10659     3.86202    10.43801
#   0  1  2     5.36762     3.53714     9.09818
#   1  0  4     3.88437     2.77157     6.32933
#   1  1  0     3.71243     2.85093     4.73132
#   0  1  5     3.33422     2.50906     4.78647
#   0  0  6     3.24950     2.55363     4.12930
#   1  1  3     3.22357     2.42261     4.73132
#   0  2  1     3.17222     2.54131     3.87786
#   2  0  2     3.05329     2.38076     4.05906
#   0  2  4     2.68381     2.14188     3.48614
#   1  0  7     2.55582     2.03840     3.36913
#   2  0  5     2.48062     1.97894     3.29222
#   1  1  6     2.44513     1.94224     3.29648
#   2  1  1     2.41169     1.99465     2.94740
#   1  2  2     2.35818     1.94542     2.91093
#   0  1  8     2.27893     1.87278     2.85635
#   2  1  4     2.17498     1.78322     2.76399
#   0  0  9     2.16634     1.83988     2.55363
# ...

# %% [markdown]
# # k-vector Search Test
#
# > Here, we generate a dummy dataset for which we have the k-vector of [0.33, 0.21, 1.5]. Given the nucleus lattice vector defined above, we pick several peaks from the `d_hkl_p_lk` and `d_hkl_p_lk` lists as those 'experimentally observed' peaks. If the implementation of k-vector search works fine, we should get back our input k vector [0.33, 0.21, 1.5]. For this test, we pick those values included in the `k_gt` dictionary.

# %%
d_list = sorted(list(k_gt.values()))

# Given the wavelength, we can turn the positions into 2Theta's,
# which are the 'experimentally observed' peak positions in
# 2Theta space.
wl = 2.4109
two_theta = [2. * np.rad2deg(np.arcsin(wl / (2. * d))) for d in d_list]

# %%
sorted(two_theta)
# Out:
# [14.721417743638689,
#  29.173461410505855,
#  29.52121729517971,
#  33.9466045669624,
#  39.85098010652728,
#  40.4592192780807,
#  42.89866183190747,
#  50.026350815863694,
#  51.56221738619436,
#  54.73338102302482,
#  56.33546474907562,
#  59.68054643095653,
#  60.839452410781654]
